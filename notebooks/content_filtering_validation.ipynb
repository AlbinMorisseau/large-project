# %% [markdown]
# # Content filtering validation

# %% [markdown]
# Thanks to the preprocessing pipeline, reviews were filtered based on their content. A dataset containing only reviews related to identified special needs (pets, children, disabilities) was created. To segment these reviews, a keyword search using regex was applied.
#
# To verify that the selected reviews are indeed relevant to special needs, a validation model can be used.
#
# Validation with a zero-shot classification model involves using a pre-trained NLP model capable of classifying text into defined categories.
#
# Four categories were defined: pets, children, disability, and others.

# %%
# 2:32
import torch
from transformers import pipeline
import polars as pl
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# --- 1. Charger le modèle Zero-Shot ---
pipe = pipeline(
    "zero-shot-classification",
    #model="facebook/bart-large-mnli"
    model = "typeform/distilbert-base-uncased-mnli"
)

# --- 2. Charger les données ---
df = pl.read_csv("../data/processed/key_word_test_a_supprimer.csv")
df = df.sample(n=1500, with_replacement=False, shuffle=True)

# --- 3. Labels à tester ---
labels = ["pet", "child", "handicap", "other"] #vrai label

#juste pour le test
#labels = ["pets", "children", "handicap", "other"]

# --- 4. Appliquer le modèle à chaque texte ---
predicted = []
texts = df["review"].to_list()

for r in texts:
    result = pipe(r, candidate_labels=labels, multi_label=False)
    predicted.append(result["labels"][0])  # catégorie avec le plus haut score

# --- 5. Ajouter la colonne dans le DataFrame ---
df = df.with_columns(pl.Series("predicted_category", predicted))

# --- 6. Comparer les colonnes avec une matrice de confusion ---
true = df["category"].to_list()
pred = df["predicted_category"].to_list()

cm = confusion_matrix(true, pred, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion matrix : keyword extraction vs. Zero-Shot Classification")
plt.show()
# Out:
# Device set to use cpu

# %% [markdown]
# model = facebook/bart-large-mnli (lourd)
# model = "typeform/distilbert-base-uncased-mnli" (plus leger)

# %% [markdown]
# Computational time (on activities)
#
# 100 -> 2:32 (lourd)
# 1000 -> 5:56 (lourd)
#
# 200 -> 0:36 (leger)
# 400 -> 1:03 (leger)
# 800 -> 2:25
# 1500 -> 10:41

# %%
import torch
torch.set_num_threads(4)
from transformers import pipeline
import polars as pl
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from tqdm import tqdm

# --- 1. Charger le modèle ---
device = 0 if torch.cuda.is_available() else -1
pipe = pipeline(
    "zero-shot-classification",
    model="typeform/distilbert-base-uncased-mnli",
    device=device
)

# --- 2. Charger les données ---
df = pl.read_csv("../data/processed/key_word_test_a_supprimer.csv")
#df = df.sample(n=1500, with_replacement=False, shuffle=True)

labels = ["pet", "child", "handicap", "other"]
texts = df["review"].to_list()

# --- 3. Prédiction par batch ---
batch_size = 32
predicted = []

for i in tqdm(range(0, len(texts), batch_size)):
    batch = texts[i:i+batch_size]
    results = pipe(batch, candidate_labels=labels, multi_label=False)
    # results est une liste de dicts
    predicted.extend([r["labels"][0] for r in results])

# --- 4. Fusionner les résultats ---
df = df.with_columns(pl.Series("predicted_category", predicted))

# --- 5. Matrice de confusion ---
true = df["category"].to_list()
pred = df["predicted_category"].to_list()

cm = confusion_matrix(true, pred, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion matrix : keyword extraction vs. Zero-Shot Classification")
plt.show()
# Out:
# Device set to use cpu
#  48%|████▊     | 75/155 [2:16:12<2:25:17, 108.96s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 30
#      28 for i in tqdm(range(0, len(texts), batch_size)):
#      29     batch = texts[i:i+batch_size]
# ---> 30     results = pipe(batch, candidate_labels=labels, multi_label=False)
#      31     # results est une liste de dicts
#      32     predicted.extend([r["labels"][0] for r in results])
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\transformers\pipelines\zero_shot_classification.py:209, in ZeroShotClassificationPipeline.__call__(self, sequences, *args, **kwargs)
#     206 else:
#     207     raise ValueError(f"Unable to understand extra arguments {args}")
# --> 209 return super().__call__(sequences, **kwargs)
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\transformers\pipelines\base.py:1448, in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1444     return self.get_iterator(
#    1445         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1446     )
#    1447 elif is_iterable:
# -> 1448     return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1449 elif self.framework == "pt" and isinstance(self, ChunkPipeline):
#    1450     return next(
#    1451         iter(
#    1452             self.get_iterator(
#    (...)   1455         )
#    1456     )
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\transformers\pipelines\pt_utils.py:126, in __next__(self)
#     124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
# --> 126 # We now have a batch of "inferred things".
#     127 if self.loader_batch_size is not None:
#     128     # Try to infer the size of the batch
#     129     if isinstance(processed, torch.Tensor):
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\transformers\pipelines\pt_utils.py:271, in __next__(self)
#     269 processed = self.infer(next(self.iterator), **self.params)
#     270 if self.loader_batch_size is not None:
# --> 271     if isinstance(processed, torch.Tensor):
#     272         first_tensor = processed
#     273     else:
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\transformers\pipelines\base.py:1374, in forward(self, model_inputs, **forward_params)
#    1371 def get_iterator(
#    1372     self, inputs, num_workers: int, batch_size: int, preprocess_params, forward_params, postprocess_params
#    1373 ):
# -> 1374     if isinstance(inputs, collections.abc.Sized):
#    1375         dataset = PipelineDataset(inputs, self.preprocess, preprocess_params)
#    1376     else:
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\transformers\pipelines\zero_shot_classification.py:232, in ZeroShotClassificationPipeline._forward(self, inputs)
#     230 if "use_cache" in inspect.signature(model_forward).parameters:
#     231     model_inputs["use_cache"] = False
# --> 232 outputs = self.model(**model_inputs)
#     234 model_outputs = {
#     235     "candidate_label": candidate_label,
#     236     "sequence": sequence,
#     237     "is_last": inputs["is_last"],
#     238     **outputs,
#     239 }
#     240 return model_outputs
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:917, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     909 r"""
#     910 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     911     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     912     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     913     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     914 """
#     915 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 917 distilbert_output = self.distilbert(
#     918     input_ids=input_ids,
#     919     attention_mask=attention_mask,
#     920     head_mask=head_mask,
#     921     inputs_embeds=inputs_embeds,
#     922     output_attentions=output_attentions,
#     923     output_hidden_states=output_hidden_states,
#     924     return_dict=return_dict,
#     925 )
#     926 hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     927 pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:736, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     731     if self._use_sdpa and head_mask_is_none and not output_attentions:
#     732         attention_mask = _prepare_4d_attention_mask_for_sdpa(
#     733             attention_mask, embeddings.dtype, tgt_len=input_shape[1]
#     734         )
# --> 736 return self.transformer(
#     737     x=embeddings,
#     738     attn_mask=attention_mask,
#     739     head_mask=head_mask,
#     740     output_attentions=output_attentions,
#     741     output_hidden_states=output_hidden_states,
#     742     return_dict=return_dict,
#     743 )
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:541, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     538 if output_hidden_states:
#     539     all_hidden_states = all_hidden_states + (hidden_state,)
# --> 541 layer_outputs = layer_module(
#     542     hidden_state,
#     543     attn_mask,
#     544     head_mask[i],
#     545     output_attentions,
#     546 )
#     548 hidden_state = layer_outputs[-1]
#     550 if output_attentions:
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\transformers\modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:476, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     466 """
#     467 Parameters:
#     468     x: torch.tensor(bs, seq_length, dim)
#    (...)    473     torch.tensor(bs, seq_length, dim) The output of the transformer block contextualization.
#     474 """
#     475 # Self-Attention
# --> 476 sa_output = self.attention(
#     477     query=x,
#     478     key=x,
#     479     value=x,
#     480     mask=attn_mask,
#     481     head_mask=head_mask,
#     482     output_attentions=output_attentions,
#     483 )
#     484 if output_attentions:
#     485     sa_output, sa_weights = sa_output  # (bs, seq_length, dim), (bs, n_heads, seq_length, seq_length)
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:390, in DistilBertSdpaAttention.forward(self, query, key, value, mask, head_mask, output_attentions)
#     387     """group heads"""
#     388     return x.transpose(1, 2).contiguous().view(batch_size, -1, self.n_heads * dim_per_head)
# --> 390 q = shape(self.q_lin(query))  # (bs, n_heads, q_length, dim_per_head)
#     391 k = shape(self.k_lin(key))  # (bs, n_heads, k_length, dim_per_head)
#     392 v = shape(self.v_lin(value))  # (bs, n_heads, k_length, dim_per_head)
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\emma\Desktop\project\large-project\venv\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# 100 -> 0:25
# 200 -> 0:40
# 400 -> 1:15
# 800 -> 2:23
# 1500 -> 4:25
